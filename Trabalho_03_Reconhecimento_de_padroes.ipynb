# %% [markdown]
# #### Imports necessários

# %%
import numpy as np
import pandas as pd
import funcoes_importantes as fi
fp = fi.funcoes_main()
base = fi.carrega_base()
derma_dados = base.derma_dados

# %% [markdown]
# ### 2) Questões
# ### 2.1) Análise incial dos dados
# a) A partir do banco de dados completo (matriz X ∈ ℝ𝑁𝑥𝑝 contendo todas os vetores de atributos), calcule:

# %% [markdown]
# - Vetor médio (média de cada atributo).

# %%
fp.vetor_medio(derma_dados)
# Out:
#          c1        c2        c3        c4        c5        c6        c7  \
# 0  2.078212  1.807263  1.569832  1.354749  0.636872  0.449721  0.170391
#
#          c8        c9       c10  ...       c25      c26       c27       c28  \
# 0  0.379888  0.622905  0.530726  ...  0.399441  0.47486  0.460894  0.949721
#
#         c29       c30       c31       c32       c33        c34
# 0  0.458101  0.106145  0.117318  1.877095  0.558659  36.296089
#
# [1 rows x 34 columns]

# %% [markdown]
# - Vetor de variâncias (variância de cada atributo).

# %%
fp.vetor_variancias(derma_dados)
# Out:
#          c1       c2        c3        c4        c5        c6       c7  \
# 0  0.442045  0.49216  0.811636  1.288367  0.825752  0.914832  0.33223
#
#          c8       c9       c10  ...       c25      c26       c27       c28  \
# 0  0.701219  0.98065  0.832387  ...  0.733557  0.75987  0.921436  1.274776
#
#         c29       c30       c31       c32       c33         c34
# 0  0.921209  0.207189  0.243901  0.489054  1.227642  234.842057
#
# [1 rows x 34 columns]

# %% [markdown]
# - Matriz de covariância

# %%
fp.matriz_covariancia(derma_dados)
# Out:
#              c1          c2         c3          c4          c5         c6  \
# c1      0.44081    0.199432    0.14817  -0.0249524 -0.00511844  0.0178989
# c2     0.199432    0.490785   0.218767   -0.057325 -0.00574264 -0.0501935
# c3      0.14817    0.218767   0.809369  -0.0596891    0.195749   0.277254
# c4   -0.0249524   -0.057325 -0.0596891     1.28477    0.288037   0.446607
# c5  -0.00511844 -0.00574264   0.195749    0.288037    0.823445   0.336491
# c6    0.0178989  -0.0501935   0.277254    0.446607    0.336491   0.912276
# c7   -0.0440529   -0.039785 -0.0915078  -0.0939655  -0.0917574 -0.0766284
# c8   -0.0185387  -0.0496863   0.210902    0.342889    0.294373   0.689492
# c9     0.090946    0.203856   0.267954   -0.332707  -0.0587216  -0.263373
# c10    0.109329    0.188883   0.214335   -0.157548   0.0111576  -0.224712
# c11   0.0378733   0.0432415  0.0333167  -0.0519803  -0.0279954 -0.0552729
# c12   0.0209575  -0.0493508   0.240879    0.362715     0.30553   0.762266
# c13   0.0195843   0.0106972 -0.0532443   0.0472286  -0.0181018  0.0113526
# c14    0.119191      0.1558  0.0260135   -0.127181   -0.122421  -0.246216
# c15   -0.183905     -0.2157  -0.188243    0.172942   -0.178677  -0.119605
# c16    0.018648  -0.0825661  -0.210106     0.26864    0.142271   0.404014
# c17   0.0398084   0.0612184   0.134406   0.0465809  -0.0246091  0.0983115
# c18   -0.020427   0.0175166  0.0494991  -0.0165335   0.0068506  -0.118153
# c19    0.131129     0.19791   0.305328  -0.0825115   -0.032396 -0.0427967
# c20     0.11582    0.242119   0.379748   -0.282334   0.0169314   -0.29772
# c30  -0.0930469   0.0594676 -0.0923778           1    0.928843  -0.0644987
# c31   -0.114378   0.0708906  -0.113699    0.928843           1  -0.0797909
# c32    0.276566   0.0205326   0.271914  -0.0644987  -0.0797909           1
# c33     0.93712   0.0449077   0.928171   -0.101246   -0.114993    0.262386
# c34    0.127609  -0.0844546   0.111493   -0.356694   -0.392484    0.081818
#
#            c33         c34
# c1  -0.0138502 -0.00502847
# c2   -0.134966   0.0160056
# c3    0.275099    0.138493
# c4    0.389887   0.0480527
# c5    0.377323   0.0811622
# c6    0.904112   0.0969535
# c7   -0.136311   -0.371368
# c8    0.890685    0.111047
# c9   -0.279753  -0.0782675
# c10  -0.255333   0.0364115
# c11  -0.189008  -0.0928576
# c12   0.919119    0.119512
# c13  0.0274086   0.0447904
# c14  -0.321341   0.0507259
# c15  -0.165074   0.0325324
# c16   0.382579  -0.0406201
# c17     0.1008   0.0466253
# c18  -0.141437  -0.0133616
# c19 -0.0727912   0.0363862
# c20  -0.301104    0.124148
# c21  -0.415707    0.124353
# c22  -0.300152    0.130903
# c23  -0.223636   0.0823164
# c24  -0.200545   0.0897333
# c25   0.906516   0.0989523
# c26  -0.144928    0.142727
# c27    0.93712    0.127609
# c28  0.0449077  -0.0844546
# c29   0.928171    0.111493
# c30  -0.101246   -0.356694
# c31  -0.114993   -0.392484
# c32   0.262386    0.081818
# c33          1    0.104556
# c34   0.104556           1
#
# [34 rows x 34 columns]
# None

# %% [markdown]
# b) A partir dos resultados obtidos no item anterior, responda:
# - Que informação, sobre os atributos, é obtida através da matriz de correlação?
# <span style='color:red;font-weight:bolder;'>
#     Que há classe altamente correlacionadas como a classe 30 e classe 31 e outra muito descorrelacionadas com a classe 28 com a classe 21.
# </span>
#
# - Quais atributos são mais correlacionados?
# <span style='color:red;font-weight:bolder;'>
#        A classe 31 com a classe 30, a classe 6 e 8 com a classe 33 entre outros
# </span>

# %% [markdown]
# ### 2.2) Classificadores Bayesianos
# - Implemente os seguintes classificadores bayesianos:

# %% [markdown]
# I) QDA (utilizando a formulação completa do discriminante bayesiano).

# %%
# Antes de tudos normalizar z-score os dados com as info do dados de treino(mean e std)
# iSSO TUDO PARA 6 CLASSES

def qda(X,y,verbose=False):
    # 1- calcula a probilidade a priori[1x1]
    probs_p = fp.prob_a_priori(X)

    # 2- vetor médio por classe[1x34]
    vt_medio = fp.vetor_medio_p_classe(X)

    
    # 3- matriz covariancia por classe[34x34]
    mcov_1 = fp.matriz_covariancia(X.query('c35==1'))
    mcov_2 = fp.matriz_covariancia(X.query('c35==2'))
    mcov_3 = fp.matriz_covariancia(X.query('c35==3'))
    mcov_4 = fp.matriz_covariancia(X.query('c35==4'))
    mcov_5 = fp.matriz_covariancia(X.query('c35==5'))
    mcov_6 = fp.matriz_covariancia(X.query('c35==6'))
    
    # 4- Fazer a correção lamdba A = A + xI na matriz de covariancia
    mcov_1_lambda = fp.correcao_lambda(mcov_1)
    mcov_2_lambda = fp.correcao_lambda(mcov_2)
    mcov_3_lambda = fp.correcao_lambda(mcov_3)
    mcov_4_lambda = fp.correcao_lambda(mcov_4)
    mcov_5_lambda = fp.correcao_lambda(mcov_5)
    mcov_6_lambda = fp.correcao_lambda(mcov_6)

    # 5- Calcular a inversa da matriz de covairância regulada lambda
    mcov_1_lambda_inv = fp.matriz_inversa(mcov_1_lambda)
    mcov_2_lambda_inv = fp.matriz_inversa(mcov_2_lambda)
    mcov_3_lambda_inv = fp.matriz_inversa(mcov_3_lambda)
    mcov_4_lambda_inv = fp.matriz_inversa(mcov_4_lambda)
    mcov_5_lambda_inv = fp.matriz_inversa(mcov_5_lambda)
    mcov_6_lambda_inv = fp.matriz_inversa(mcov_6_lambda)

    # 6- Calcular o determinante de cada matriz de covariância regulada
    det_1 = fp.determinante_matriz_covariancia(mcov_1_lambda)
    det_2 = fp.determinante_matriz_covariancia(mcov_2_lambda)
    det_3 = fp.determinante_matriz_covariancia(mcov_3_lambda)
    det_4 = fp.determinante_matriz_covariancia(mcov_4_lambda)
    det_5 = fp.determinante_matriz_covariancia(mcov_5_lambda)
    det_6 = fp.determinante_matriz_covariancia(mcov_6_lambda)


    # Teste, pegar agora um elementro da base de teste e aplicar
    # min: ln|det(mcov_classe_i)| + 
    #       (elem_teste-vetor_medio_classe_i).T*mcov_classe_i_inv*(elem_teste-vetor_md_classe_i)
    #       - 2*ln(P_priori(classe_i)) 

    # elem_teste é X da questão, literalmente
    # o que o min retorna?
    # min retorna um valor 1,2,3,4,5,6 sendo este a classe

    aux = []
    for i in y.index.values:
        valores = []
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[0],mcov_1_lambda_inv,det_1,probs_p[0]))    
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[1],mcov_2_lambda_inv,det_2,probs_p[1]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[2],mcov_3_lambda_inv,det_3,probs_p[2]))    
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[3],mcov_4_lambda_inv,det_4,probs_p[3]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[4],mcov_5_lambda_inv,det_5,probs_p[4]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio.iloc[5],mcov_6_lambda_inv,det_6,probs_p[5]))
        aux.append(valores.index(min(valores))+1)
    if verbose:
        print('Acrurácia de ',fp.get_acc(aux,y['c35'])*100,'%')
    return fp.get_acc(aux,y['c35'])

# %%
qda_accs = []
for _ in range(5):
    X,y = fp.kfold_shuffle(5)
    qda_accs.append(qda(X,y,verbose=True))
print(f'Acurácia média de {np.mean(qda_accs)*100}%')
# Out:
# Acrurácia de  98.61 %
# Acrurácia de  97.22 %
# Acrurácia de  98.61 %
# Acrurácia de  93.06 %
# Acrurácia de  98.61 %
# Acurácia média de 97.22200000000001%

# %% [markdown]
# II) Naive Bayes (considerando que os atributos do problema são descorrelacionados)

# %%
def naives_bayes(X,y,verbose=False):
    # 1- calcula a probilidade a priori[1x1]
    probs_p = fp.prob_a_priori(X)

    # 2- vetor médio por classe[1x34]
    vt_medio_1 = fp.vetor_medio(X.query('c35==1'))
    vt_medio_2 = fp.vetor_medio(X.query('c35==2'))
    vt_medio_3 = fp.vetor_medio(X.query('c35==3'))
    vt_medio_4 = fp.vetor_medio(X.query('c35==4'))
    vt_medio_5 = fp.vetor_medio(X.query('c35==5'))
    vt_medio_6 = fp.vetor_medio(X.query('c35==6'))
    
    mcov_1 = fp.matriz_covariancia(X.query('c35==1'))
    mcov_2 = fp.matriz_covariancia(X.query('c35==2'))
    mcov_3 = fp.matriz_covariancia(X.query('c35==3'))
    mcov_4 = fp.matriz_covariancia(X.query('c35==4'))
    mcov_5 = fp.matriz_covariancia(X.query('c35==5'))
    mcov_6 = fp.matriz_covariancia(X.query('c35==6'))

    # 3- matriz covariancia por classe[34x34] sabendo que são descorrelacionados
    mcov_1_descorrelacionada = fp.limpar_covariancia(mcov_1)
    mcov_2_descorrelacionada = fp.limpar_covariancia(mcov_2)
    mcov_3_descorrelacionada = fp.limpar_covariancia(mcov_3)
    mcov_4_descorrelacionada = fp.limpar_covariancia(mcov_4)
    mcov_5_descorrelacionada = fp.limpar_covariancia(mcov_5)
    mcov_6_descorrelacionada = fp.limpar_covariancia(mcov_6)

    # 4- Fazer a correção lamdba A = A + xI na matriz de covariancia
    mcov_1_lambda = fp.correcao_lambda(mcov_1)
    mcov_2_lambda = fp.correcao_lambda(mcov_2)
    mcov_3_lambda = fp.correcao_lambda(mcov_3)
    mcov_4_lambda = fp.correcao_lambda(mcov_4)
    mcov_5_lambda = fp.correcao_lambda(mcov_5)
    mcov_6_lambda = fp.correcao_lambda(mcov_6)

    # 5- Calcular a inversa da matriz de covairância regulada lambda
    mcov_1_lambda_inv = fp.matriz_inversa(mcov_1_lambda)
    mcov_2_lambda_inv = fp.matriz_inversa(mcov_2_lambda)
    mcov_3_lambda_inv = fp.matriz_inversa(mcov_3_lambda)
    mcov_4_lambda_inv = fp.matriz_inversa(mcov_4_lambda)
    mcov_5_lambda_inv = fp.matriz_inversa(mcov_5_lambda)
    mcov_6_lambda_inv = fp.matriz_inversa(mcov_6_lambda)
    
    # 6- Calcular o determinante de cada matriz de covariância regulada
    det_1 = fp.determinante_matriz_covariancia(mcov_1_lambda)
    det_2 = fp.determinante_matriz_covariancia(mcov_2_lambda)
    det_3 = fp.determinante_matriz_covariancia(mcov_3_lambda)
    det_4 = fp.determinante_matriz_covariancia(mcov_4_lambda)
    det_5 = fp.determinante_matriz_covariancia(mcov_5_lambda)
    det_6 = fp.determinante_matriz_covariancia(mcov_6_lambda)
    
    # 5- Teste, pegar agora um elementro da base de teste e aplicar
    # min: ln|det(mcov_classe_i)| + 
    #       (elem_teste-vetor_medio_classe_i).T*mcov_classe_i_inv*(elem_teste-vetor_md_classe_i)
    #       - 2*ln(P_priori(classe_i)) 
    aux = []
    for i in y.index.values:
        valores = []
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_1,mcov_1_lambda_inv,det_1,probs_p[0]))    
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_2,mcov_2_lambda_inv,det_2,probs_p[1]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_3,mcov_3_lambda_inv,det_3,probs_p[2]))    
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_4,mcov_4_lambda_inv,det_4,probs_p[3]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_5,mcov_5_lambda_inv,det_5,probs_p[4]))
        valores.append(fp.teste_elem(y.iloc[i,:-1],vt_medio_6,mcov_6_lambda_inv,det_6,probs_p[5]))
        aux.append(valores.index(min(valores))+1)
    if verbose: print('Acrurácia de ',fp.get_acc(aux,y['c35'])*100,'%')
    return fp.get_acc(aux,y['c35'])

# %%
naive_bayes_accs = []
for _ in range(5):
    X,y = fp.kfold_shuffle(5)
    naive_bayes_accs.append(naives_bayes(X,y,verbose=True))
print(f'Acurácia média de {np.mean(naive_bayes_accs)*100}%')
# Out:
# Acrurácia de  97.22 %
# Acrurácia de  95.83 %
# Acrurácia de  88.89 %
# Acrurácia de  95.83 %
# Acrurácia de  98.61 %
# Acurácia média de 95.276%

# %% [markdown]
# III) LDA (considerando que todos os classificadores possuem a mesma matriz de covariância e a mesma probabilidade à priori).
#
# • OBS: para calcular a matriz de covariância agregada, deve-se calcular as matrizes de covariância de cada classe, e calcular a média destas.
#
# - Para cada classificador, utilizando o banco de dados “dermatologia” realize o seguinte experimento:
#
#     + Utilize a validação cruzada k-fold (k = 5) para gerar os resultados.
#     + Para cada um dos 5 particionamentos dos dados (entre treinamento e teste) realize o seguinte procedimento:
#         + A partir dos dados de treinamento, calcule a média e o desvio padrão de cada atributo e faça a normalização z-score dos dados (tanto dos dados de treinamento como dos dados de teste).
#         + Calcule as estatísticas necessárias (matriz de covariância, vetor médio, probabilidade a priori...), para o classificador, a partir dos dados de treinamento.
#         + Classifique os dados de teste.

# %%
def lda(X,y,verbose=False):
    # 1- vetor médio por classe[1x34]
    vt_medio_1 = fp.vetor_medio(X.query('c35==1'))
    vt_medio_2 = fp.vetor_medio(X.query('c35==2'))
    vt_medio_3 = fp.vetor_medio(X.query('c35==3'))
    vt_medio_4 = fp.vetor_medio(X.query('c35==4'))
    vt_medio_5 = fp.vetor_medio(X.query('c35==5'))
    vt_medio_6 = fp.vetor_medio(X.query('c35==6'))


    # 2- mcov_medio ou agregaddo é [34x34] somar todas as mcov de n classes e fazer a média mcov/n classes [34x34]
    mcov_1 = fp.matriz_covariancia(X.query('c35==1'))
    mcov_2 = fp.matriz_covariancia(X.query('c35==2'))
    mcov_3 = fp.matriz_covariancia(X.query('c35==3'))
    mcov_4 = fp.matriz_covariancia(X.query('c35==4'))
    mcov_5 = fp.matriz_covariancia(X.query('c35==5'))
    mcov_6 = fp.matriz_covariancia(X.query('c35==6'))
    mcov_medio = mcov_1+mcov_2+mcov_3+mcov_4+mcov_5+mcov_6
    mcov_medio = mcov_medio/6

    # 3- Fazer a correção lamdba A = A + xI na matriz de covariancia
    mcov_medio_lambda = fp.correcao_lambda(mcov_medio)
 
    # 5- Calcular a inversa da matriz de covairância regulada lambda
    mcov_medio_lambda_inv_d = fp.matriz_inversa(mcov_medio_lambda)
    
    # 4- Teste, pegar agora um elementro da base de teste e aplicar
    # min: (elem_teste-vetor_medio_classe_i).T*mcov_classe_i_inv_media(agredada)*(elem_teste-vetor_md_classe_i)
    aux = []
    for i in y.index.values:
        valores = []
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_1,mcov_medio_lambda_inv_d))    
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_2,mcov_medio_lambda_inv_d))
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_3,mcov_medio_lambda_inv_d))    
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_4,mcov_medio_lambda_inv_d))
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_5,mcov_medio_lambda_inv_d))
        valores.append(fp.teste_elem_lda(y.iloc[i,:-1],vt_medio_6,mcov_medio_lambda_inv_d))
        aux.append(valores.index(min(valores))+1)
    if verbose: print('Acrurácia de ',fp.get_acc(aux,y['c35'])*100,'%')
    return fp.get_acc(aux,y['c35'])

# %%
lda_accs = []
for _ in range(5):
    X,y = fp.kfold_shuffle(5)
    lda_accs.append(lda(X,y,verbose=True))
print(f'Acurácia média de {np.mean(lda_accs)*100}%')
# Out:
# Acrurácia de  98.61 %
# Acrurácia de  100.0 %
# Acrurácia de  93.06 %
# Acrurácia de  95.83 %
# Acrurácia de  98.61 %
# Acurácia média de 97.22200000000001%

# %% [markdown]
# - Qual classificador obteve a melhor taxa de acerto (precisão, acurácia) média?
#
#     <span style='color:red;font-weight:bolder;'>LDA seguindo do QDA e em utlimo Naive Bayes.</span>
#
#
# - Pode-se considerar esse problema linearmente separável? Justifique.
#
#     <span style='color:red;font-weight:bolder;'>Sim, pois levando em conta a definição de problema linearmente separável que são algoritmos que procuram padrões a partir de um superficies de decisão, ou seja, ajustam uma hiperplano para separar os dados de cada classe. Logo, os classificadores $\textit{Quadratic Discriminat Analysis}$,$\textit{Linear Discriminat Analysis}$ e $\textit{Naive Bayes Classifier}$ utilizam da projeção dos dados para ajustar um hiperplano ideal para eles.</span>

# %% [markdown]
# 2.3) LDA (CDA) como transformação linear.
# - A partir do banco de dados dermatologia, realize o seguinte experimento:
#     + Separe os dados entre treinamento (70%) e teste (30%).
#     + A partir dos dados de treinamento, calcule a média e o desvio padrão de cada atributo e faça a normalização z-score dos dados (tanto dos dados de treinamento como dos dados de teste).
#     + A partir dos dados de treinamento, aplique o método LDA utilizando a abordagem de múltiplas projeções (também conhecido como Canonical Discriminant Analysis, CDA).
#     + A partir dos autovalores calculados, defina uma quantidade de atributos necessária para realizar a projeção dos dados. (Obs: quantidade máxima = “número de classes – 1”)
#     + Defina a matriz de projeção W.
#     + Transforme os dados de treinamento a partir da matriz W.
#     + Utilize os dados transformados para treinar um classificador bayesiano (à sua escolha)
#     + Utilize a matriz de projeção transformar os dados de teste.
#     + Classifique os dados de teste e obtenha a taxa de acerto do classificador.

# %%
def CDA(X):    
    # 1 - pegar as matrizes de covariancia
    mcov_1 = fp.matriz_covariancia(X.query('c35==1'))
    mcov_2 = fp.matriz_covariancia(X.query('c35==2'))
    mcov_3 = fp.matriz_covariancia(X.query('c35==3'))
    mcov_4 = fp.matriz_covariancia(X.query('c35==4'))
    mcov_5 = fp.matriz_covariancia(X.query('c35==5'))
    mcov_6 = fp.matriz_covariancia(X.query('c35==6'))
    
    # 2 - matriz de covairanci Sw
    Sw = mcov_1+mcov_2+mcov_3+mcov_4+mcov_5+mcov_6
    
    # 3 - Calcular o vetor médio de cada classse
    u1 = fp.vetor_medio(X.query('c35==1'))
    u2 = fp.vetor_medio(X.query('c35==2'))
    u3 = fp.vetor_medio(X.query('c35==3'))
    u4 = fp.vetor_medio(X.query('c35==4'))
    u5 = fp.vetor_medio(X.query('c35==5'))
    u6 = fp.vetor_medio(X.query('c35==6'))
    
    # 4 - Calcular a media dos vetores médios
    u = (u1+u2+u3+u4+u5+u6)/6
    
    # 5 - Calcular a projeção 
    sb1 = fp.calcula_projecao(X.query('c35==1'),u,u1)
    sb2 = fp.calcula_projecao(X.query('c35==2'),u,u2)
    sb3 = fp.calcula_projecao(X.query('c35==3'),u,u3)
    sb4 = fp.calcula_projecao(X.query('c35==4'),u,u4)
    sb5 = fp.calcula_projecao(X.query('c35==5'),u,u5)
    sb6 = fp.calcula_projecao(X.query('c35==6'),u,u6)
    
    # 6 - Somar os  Sb's
    Sb = sb1+sb2+sb3+sb4+sb5+sb6
    
    m_aa_av = fp.matriz_inversa(Sw)*Sb
    
    a_valores,a_vetores = np.linalg.eig(m_aa_av)
    df_a_valores = pd.DataFrame(a_valores)
    df_a_vetores = pd.DataFrame(a_vetores)
    
    W = pd.DataFrame({})
    for i in df_a_valores.sort_values(by=0,ascending=True)[:5].index.values:
        W = W.append(df_a_vetores.iloc[i],ignore_index=True)

    return W

# %%
naives_bayes_accs = []
for _ in range(5):
    X,y = fp.treino_teste_70_30(derma_dados)
    W = CDA(X)
    Xtr_t =  fp.transformar_dados(W,X)
    Xts_t =  fp.transformar_dados(W,y)
    naives_bayes_accs.append(naives_bayes(Xtr_t,Xts_t,verbose=True))
print(f'Acurácia média de {np.mean(naives_bayes_accs)*100}%')
# Out:
# Acrurácia de  73.83 %
# Acrurácia de  75.7 %
# Acrurácia de  80.36999999999999 %
# Acrurácia de  69.16 %
# Acrurácia de  77.57 %
# Acurácia média de 75.326%

# %%
qda_accs = []
for _ in range(5):
    X,y = fp.treino_teste_70_30(derma_dados)
    W = CDA(X)
    Xtr_t =  fp.transformar_dados(W,X)
    Xts_t =  fp.transformar_dados(W,y)
    qda_accs.append(qda(Xtr_t,Xts_t,verbose=True))
print(f'Acurácia média de {np.mean(qda_accs)*100}%')
# Out:
# Acrurácia de  74.77000000000001 %
# Acrurácia de  90.64999999999999 %
# Acrurácia de  83.17999999999999 %
# Acrurácia de  89.72 %
# Acrurácia de  85.05 %
# Acurácia média de 84.67399999999999%

# %%
lda_accs = []
for _ in range(5):
    X,y = fp.treino_teste_70_30(derma_dados)
    W = CDA(X)
    Xtr_t =  fp.transformar_dados(W,X)
    Xts_t =  fp.transformar_dados(W,y)
    lda_accs.append(lda(Xtr_t,Xts_t,verbose=True))
print(f'Acurácia média de {np.mean(lda_accs)*100}%')
# Out:
# Acrurácia de  79.44 %
# Acrurácia de  91.59 %
# Acrurácia de  77.57 %
# Acrurácia de  84.11 %
# Acrurácia de  81.31 %
# Acurácia média de 82.804%
